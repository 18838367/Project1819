# %%
import numpy as np
from matplotlib import *
# %matplotlib inline
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
rcParams['figure.figsize']=(10,6)
rcParams.update({'font.size': 14})

# %%
positions=np.random.rand(10,3,10)
positions2=positions-(np.random.rand(10,3,10)/100)
positions3=positions2-(np.random.rand(10,3,10)/100)
positions4=positions3-(np.random.rand(10,3,10)/100)
positions5=positions4-(np.random.rand(10,3,10)/100)
positions6=positions5-(np.random.rand(10,3,10)/100)
positions7=positions6-(np.random.rand(10,3,10)/100)

# %%
positions[:,0,1]
# Out:
# array([ 0.89440272,  0.55259204,  0.81846723,  0.57960188,  0.13747884,
#         0.53103131,  0.88932872,  0.42157415,  0.38615222,  0.71062525])

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(positions[:,0,0], positions[:,1,0], positions[:,2,0])
ax.scatter(positions2[:,0,0], positions2[:,1,0], positions2[:,2,0])
ax.scatter(positions3[:,0,0], positions3[:,1,0], positions3[:,2,0])
ax.scatter(positions4[:,0,0], positions4[:,1,0], positions4[:,2,0])
ax.scatter(positions5[:,0,0], positions5[:,1,0], positions5[:,2,0])
ax.scatter(positions6[:,0,0], positions6[:,1,0], positions6[:,2,0])
ax.scatter(positions7[:,0,0], positions7[:,1,0], positions7[:,2,0])
plt.show()

# %%
chi2=np.zeros([16, 4])
for i in range(4):
    chi2[:,i]=np.load('PSOoutput/tracks/track'+str(i+1)+'.npy')
print(chi2)
pos=np.zeros([16,3,4])
for i in range(4):
    pos[:,:,i]=np.load('PSOoutput/tracks/trackP'+str(i+1)+'.npy')
print(pos)
print(np.shape(pos))
# Out:
# [[ 195.88007194  195.88007194  195.88007194  195.88007194]
#  [ 195.88007194  206.54771912  206.54771912  195.88007194]
#  [ 195.88007194  195.88007194  195.88007194  195.88007194]
#  [ 195.88007194  195.88007194  195.88007194  195.88007194]
#  [ 195.88007194  195.88007194  195.88007194  195.88007194]
#  [ 195.88007194  195.88007194  195.88007194  195.88007194]
#  [ 195.88007194  195.88007194  195.88007194  195.88007194]
#  [ 195.88007194  195.88007194  195.88007194  195.88007194]
#  [ 195.88007194  195.88007194  195.88007194  195.88007194]
#  [ 195.88007194  195.88007194  195.88007194  195.88007194]
#  [ 195.88007194  195.88007194  195.88007194  195.88007194]
#  [ 195.88007194  195.88007194  195.88007194  195.88007194]
#  [ 195.88007194  195.88007194  195.88007194  195.88007194]
#  [ 195.88007194  195.88007194  195.88007194  195.88007194]
#  [ 195.88007194  195.88007194  195.88007194  195.88007194]
#  [ 195.88007194  195.88007194  195.88007194  195.88007194]]
# ...

# %%
np.load('PSOoutput/tracks/trackP100.npy')
# Out:
# array([[ 1.18080435,  9.66510718, -1.61292313],
#        [ 1.00277286,  9.85779245, -1.71984064],
#        [ 1.03670598,  9.73289183, -1.51446762],
#        [ 1.00438885,  9.79036662, -1.3856316 ],
#        [ 1.00255928,  9.58049452, -1.44578702],
#        [ 1.00303762,  9.87935188, -1.76983843],
#        [ 1.003439  ,  9.60218627, -1.6084833 ],
#        [ 1.00265726,  9.83022005, -1.56690451],
#        [ 1.00229878,  9.73073024, -1.52525054],
#        [ 1.00219548,  9.71654838, -1.46621703],
#        [ 1.00133779,  9.71359608, -1.45936381],
#        [ 1.00290632,  9.78732525, -1.49972784],
#        [ 1.00209891,  9.38834753, -1.50311349],
#        [ 1.00330975,  9.36460064, -1.48259805],
#        [ 1.00343533,  9.74462902, -1.51554599],
#        [ 1.0036537 ,  9.80961092, -1.53668818],
#        [ 1.00295814,  9.61556247, -1.74506132],
#        [ 1.00276456,  9.57119577, -1.70298694],
#        [ 1.0024385 ,  9.80511204, -1.50897414],
#        [ 1.00343155,  9.75568597, -1.48230706],
# ...

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
for i in range(4):
    ax.plot(np.arange(4), chi2[i,:], label='Particle '+str(i))
#plt.legend()
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
for i in range(4):
    ax.plot(np.arange(4), chi2[i,0:], label='Particle '+str(i))
#plt.legend()
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
for i in range(16):
    ax.plot(pos[i, 0, :], pos[i,1,:], pos[i, 2, :])
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
# ax2 = fig.add_subplot(111, projection='3d')
colors = cm.hsv(chi2/np.amax(chi2))
colmap = cm.ScalarMappable(cmap=cm.hsv)
colmap.set_array(chi2)
for i in range(4):
    yg = ax.scatter(pos[:,0,i], pos[:,1,i], pos[:,2,i], c=colors[:,i], marker='o')
cb = fig.colorbar(colmap)
# for i in range(1):
#     ax2.plot(pos[:, 0, i+90], pos[:,1,i+90], pos[:, 2, i+90])

plt.show()
